# %%
import pandas as pd

# %%
def processed_data (csv_name):

    ''' csv_name (sem a extensão ".csv")
    '''

    data = pd.read_csv(csv_name+".csv")

    data = data.sort_values(["Model", "Missing Rate (%)"])

    data = data.reset_index()

    data = data.drop(columns=["index"])

    # Create a list with values from 0 to 4 repeated
    list = [i for i in range(5)]

    my_list = []

    for i in range( int(len(data)/5) ):
        for j in list:
            my_list.append(j)

    data["Repetição"] = my_list

    data_teste = pd.pivot_table(data, values=['Teste'], index=["Dataset", "Missing Rate (%)", "Repetição"], columns=['Model'])

    data = data_teste.reset_index(0)

    #solucionando nome colunas
    data.columns = [ ''.join(x) for x in data.columns ]

    data = data.reset_index()

    data.columns = ["Missing Rate", "Repetição", "Dataset", "knn","lpr0","lpr1","lpr2","lpr3","mean","mice","pmivae","saei"]

    data = data.drop(columns=["Missing Rate","Repetição","Dataset","lpr0","lpr1","lpr3"])

    data = data[["mean","knn","mice","pmivae","saei","lpr2"]]

    # fazendo o complemento para o teste estatístico

    data_processed = data.max().max() + data.min().min() - data

    print(data_processed)

    data_processed.to_csv(csv_name+"_processed_todos.csv", index=False)

# %%
ls
# Out:
# MAR-CORRELATED.csv                  MNAR-MBOUV-RANDOMNESS.csv
# MAR-CORRELATED_processed_todos.csv  MNAR-MBOUV-RANDOMNESS_processed_todos.csv
# MAR-MEDIAN.csv                      select.ipynb
# MAR-MEDIAN_processed_todos.csv      todos.csv
# MNAR-MBOUV.csv                      todos_processed_todos.csv
# MNAR-MBOUV_processed_todos.csv

# %%
processed_data("MAR-MEDIAN")
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    1.172265  1.154759  1.166659  1.030084  1.112923  1.104717
# 1    1.142833  1.131012  1.145566  1.110545  1.055186  1.062691
# 2    1.011033  1.036394  1.132852  1.047068  1.169325  1.157005
# 3    1.135390  1.193820  1.214035  1.117126  1.190885  1.166643
# 4    1.095485  1.089303  1.173499  1.136361  1.013087  1.144809
# ..        ...       ...       ...       ...       ...       ...
# 195  1.171172  1.219753  1.235650  1.165114  1.147228  1.177735
# 196  1.174108  1.227012  1.248440  1.167624  1.164047  1.199261
# 197  1.159523  1.226068  1.239073  1.158168  1.162691  1.195814
# 198  1.177541  1.230145  1.251771  1.179413  1.178648  1.200869
# 199  1.157862  1.229141  1.184886  1.165691  1.165198  1.190627
#
# [200 rows x 6 columns]

# %%
processed_data("MAR-CORRELATED")
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    1.229045  1.283465  1.266975  1.178959  1.278939  1.269651
# 1    1.193537  1.292574  1.240270  1.164687  1.187465  1.259726
# 2    1.136578  1.162866  1.100826  1.141348  1.085509  1.123362
# 3    1.305824  1.327734  1.330771  1.262200  1.324018  1.285644
# 4    1.192661  1.211574  1.192002  1.168986  1.230758  1.170639
# ..        ...       ...       ...       ...       ...       ...
# 195  1.220516  1.307474  1.360681  1.218994  1.320774  1.276046
# 196  1.225423  1.315348  1.362318  1.223749  1.262999  1.289470
# 197  1.212273  1.309588  1.368568  1.211755  1.288828  1.280972
# 198  1.242740  1.332569  1.370295  1.240214  1.346676  1.304222
# 199  1.249238  1.327209  1.367774  1.248310  1.270519  1.308016
#
# [200 rows x 6 columns]

# %%
processed_data("MNAR-MBOUV")
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    1.401698  1.413831  1.425142  1.331426  1.381835  1.489562
# 1    1.422327  1.398370  1.314183  1.323351  1.399428  1.389687
# 2    1.328174  1.358929  1.354602  1.370779  1.270845  1.380875
# 3    1.411913  1.422100  1.400219  1.453140  1.415396  1.430364
# 4    1.444764  1.357134  1.399733  1.379718  1.354202  1.397853
# ..        ...       ...       ...       ...       ...       ...
# 195  1.434382  1.453541  1.474394  1.429997  1.418992  1.432747
# 196  1.442231  1.467013  1.477491  1.447283  1.381546  1.453178
# 197  1.437945  1.465988  1.456634  1.434431  1.403004  1.447376
# 198  1.450621  1.470445  1.476954  1.451619  1.440214  1.465067
# 199  1.441777  1.455002  1.460524  1.434636  1.429367  1.432681
#
# [200 rows x 6 columns]

# %%
processed_data("MNAR-MBOUV-RANDOMNESS")
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    0.974932  0.977890  1.008992  0.906025  0.969005  1.037262
# 1    0.963744  1.001464  0.980145  0.904129  0.958986  0.974906
# 2    0.988302  0.976567  0.980712  0.942276  1.026632  0.974720
# 3    0.987728  1.020336  1.020184  0.938715  1.041736  1.008426
# 4    0.994596  1.015086  1.028237  0.971722  1.028107  1.024404
# ..        ...       ...       ...       ...       ...       ...
# 195  1.012630  1.060527  1.064595  1.013561  1.064268  1.051265
# 196  1.013824  1.067681  1.062913  1.013891  1.074676  1.056497
# 197  1.009077  1.061725  1.059370  1.008510  1.079277  1.047360
# 198  1.024099  1.077706  1.075544  1.022399  1.082990  1.063556
# 199  1.023828  1.066897  1.067658  1.025434  1.066184  1.062669
#
# [200 rows x 6 columns]

# %%
data = pd.read_csv("todos.csv")

data = data.sort_values(["Model", "Missing Rate (%)"])

data = data.reset_index()

data = data.drop(columns=["index"])

data
# Out:
#      Model          Dataset  Missing Rate (%) Métrica     Teste  \
# 0      knn      sylva_prior                10     MAE  0.045658
# 1      knn      sylva_prior                10     MAE  0.044175
# 2      knn      sylva_prior                10     MAE  0.042971
# 3      knn      sylva_prior                10     MAE  0.038444
# 4      knn      sylva_prior                10     MAE  0.034816
# ...    ...              ...               ...     ...       ...
# 7195  saei  thoracic_surgey                60     MAE  0.122481
# 7196  saei  thoracic_surgey                60     MAE  0.148403
# 7197  saei  thoracic_surgey                60     MAE  0.109262
# 7198  saei  thoracic_surgey                60     MAE  0.127485
# 7199  saei  thoracic_surgey                60     MAE  0.140759
#
#                   Mecanismo
# 0                MAR-MEDIAN
# 1                MAR-MEDIAN
# 2                MAR-MEDIAN
# 3                MAR-MEDIAN
# 4                MAR-MEDIAN
# ...                     ...
# 7195  MNAR-MBOUV-RANDOMNESS
# 7196  MNAR-MBOUV-RANDOMNESS
# 7197  MNAR-MBOUV-RANDOMNESS
# 7198  MNAR-MBOUV-RANDOMNESS
# 7199  MNAR-MBOUV-RANDOMNESS
#
# [7200 rows x 6 columns]

# %%
# Create a list with values from 0 to 4 repeated
list = [i for i in range(5)]

my_list = []

for i in range( int(len(data)/5) ):
    for j in list:
        my_list.append(j)

len(my_list)
# Out:
# 7200

# %%
data["Repetição"] = my_list

data
# Out:
#      Model          Dataset  Missing Rate (%) Métrica     Teste  \
# 0      knn      sylva_prior                10     MAE  0.045658
# 1      knn      sylva_prior                10     MAE  0.044175
# 2      knn      sylva_prior                10     MAE  0.042971
# 3      knn      sylva_prior                10     MAE  0.038444
# 4      knn      sylva_prior                10     MAE  0.034816
# ...    ...              ...               ...     ...       ...
# 7195  saei  thoracic_surgey                60     MAE  0.122481
# 7196  saei  thoracic_surgey                60     MAE  0.148403
# 7197  saei  thoracic_surgey                60     MAE  0.109262
# 7198  saei  thoracic_surgey                60     MAE  0.127485
# 7199  saei  thoracic_surgey                60     MAE  0.140759
#
#                   Mecanismo  Repetição
# 0                MAR-MEDIAN          0
# 1                MAR-MEDIAN          1
# 2                MAR-MEDIAN          2
# 3                MAR-MEDIAN          3
# 4                MAR-MEDIAN          4
# ...                     ...        ...
# 7195  MNAR-MBOUV-RANDOMNESS          0
# 7196  MNAR-MBOUV-RANDOMNESS          1
# 7197  MNAR-MBOUV-RANDOMNESS          2
# 7198  MNAR-MBOUV-RANDOMNESS          3
# 7199  MNAR-MBOUV-RANDOMNESS          4
#
# [7200 rows x 7 columns]

# %%
data_teste = pd.pivot_table(data, values=['Teste'], index=["Dataset", "Missing Rate (%)", "Mecanismo", "Repetição"], columns=['Model'])

data = data_teste.reset_index(0)

data
# Out:
#                                                      Dataset     Teste  \
# Model                                                              knn
# Missing Rate (%) Mecanismo             Repetição
# 10               MAR-CORRELATED        0          bc_coimbra  0.129019
#                                        1          bc_coimbra  0.119910
#                                        2          bc_coimbra  0.249618
#                                        3          bc_coimbra  0.084749
#                                        4          bc_coimbra  0.200910
# ...                                                      ...       ...
# 60               MNAR-MBOUV-RANDOMNESS 0            wiscosin  0.113064
#                                        1            wiscosin  0.105910
#                                        2            wiscosin  0.111867
#                                        3            wiscosin  0.095886
#                                        4            wiscosin  0.106695
#
#                                                                       \
# Model                                                 lpr0      lpr1
# Missing Rate (%) Mecanismo             Repetição
# 10               MAR-CORRELATED        0          0.135965  0.137268
#                                        1          0.146770  0.140124
#                                        2          0.269930  0.285282
#                                        3          0.112128  0.109669
#                                        4          0.240769  0.240873
# ...                                                    ...       ...
# 60               MNAR-MBOUV-RANDOMNESS 0          0.122953  0.123102
#                                        1          0.119730  0.116453
#                                        2          0.126651  0.124964
#                                        3          0.108262  0.108475
#                                        4          0.109942  0.112957
#
#                                                                       \
# Model                                                 lpr2      lpr3
# Missing Rate (%) Mecanismo             Repetição
# 10               MAR-CORRELATED        0          0.142833  0.134720
#                                        1          0.152758  0.140088
#                                        2          0.289122  0.285499
#                                        3          0.126839  0.112653
#                                        4          0.241845  0.240810
# ...                                                    ...       ...
# 60               MNAR-MBOUV-RANDOMNESS 0          0.122326  0.119135
#                                        1          0.117095  0.117327
#                                        2          0.126231  0.125605
#                                        3          0.110035  0.109031
#                                        4          0.110922  0.110107
#
#                                                                       \
# Model                                                 mean      mice
# Missing Rate (%) Mecanismo             Repetição
# 10               MAR-CORRELATED        0          0.183439  0.145508
#                                        1          0.218947  0.172214
#                                        2          0.275906  0.311658
#                                        3          0.106660  0.081713
#                                        4          0.219823  0.220482
# ...                                                    ...       ...
# 60               MNAR-MBOUV-RANDOMNESS 0          0.160961  0.108997
#                                        1          0.159768  0.110679
#                                        2          0.164514  0.114222
#                                        3          0.149492  0.098048
#                                        4          0.149763  0.105933
#
#
# Model                                               pmivae      saei
# Missing Rate (%) Mecanismo             Repetição
# 10               MAR-CORRELATED        0          0.233525  0.133545
#                                        1          0.247797  0.225019
#                                        2          0.271136  0.326975
#                                        3          0.150283  0.088466
#                                        4          0.243498  0.181726
# ...                                                    ...       ...
# 60               MNAR-MBOUV-RANDOMNESS 0          0.160031  0.109323
#                                        1          0.159701  0.098915
#                                        2          0.165082  0.094315
#                                        3          0.151192  0.090601
#                                        4          0.148158  0.107407
#
# [800 rows x 10 columns]

# %%
#solucionando nome colunas
data.columns = [ ''.join(x) for x in data.columns ]

data = data.reset_index()

data
# Out:
#      Missing Rate (%)              Mecanismo  Repetição     Dataset  Testeknn  \
# 0                  10         MAR-CORRELATED          0  bc_coimbra  0.129019
# 1                  10         MAR-CORRELATED          1  bc_coimbra  0.119910
# 2                  10         MAR-CORRELATED          2  bc_coimbra  0.249618
# 3                  10         MAR-CORRELATED          3  bc_coimbra  0.084749
# 4                  10         MAR-CORRELATED          4  bc_coimbra  0.200910
# ..                ...                    ...        ...         ...       ...
# 795                60  MNAR-MBOUV-RANDOMNESS          0    wiscosin  0.113064
# 796                60  MNAR-MBOUV-RANDOMNESS          1    wiscosin  0.105910
# 797                60  MNAR-MBOUV-RANDOMNESS          2    wiscosin  0.111867
# 798                60  MNAR-MBOUV-RANDOMNESS          3    wiscosin  0.095886
# 799                60  MNAR-MBOUV-RANDOMNESS          4    wiscosin  0.106695
#
#      Testelpr0  Testelpr1  Testelpr2  Testelpr3  Testemean  Testemice  \
# 0     0.135965   0.137268   0.142833   0.134720   0.183439   0.145508
# 1     0.146770   0.140124   0.152758   0.140088   0.218947   0.172214
# 2     0.269930   0.285282   0.289122   0.285499   0.275906   0.311658
# 3     0.112128   0.109669   0.126839   0.112653   0.106660   0.081713
# 4     0.240769   0.240873   0.241845   0.240810   0.219823   0.220482
# ..         ...        ...        ...        ...        ...        ...
# 795   0.122953   0.123102   0.122326   0.119135   0.160961   0.108997
# 796   0.119730   0.116453   0.117095   0.117327   0.159768   0.110679
# 797   0.126651   0.124964   0.126231   0.125605   0.164514   0.114222
# 798   0.108262   0.108475   0.110035   0.109031   0.149492   0.098048
# 799   0.109942   0.112957   0.110922   0.110107   0.149763   0.105933
#
#      Testepmivae  Testesaei
# 0       0.233525   0.133545
# 1       0.247797   0.225019
# 2       0.271136   0.326975
# 3       0.150283   0.088466
# 4       0.243498   0.181726
# ..           ...        ...
# 795     0.160031   0.109323
# 796     0.159701   0.098915
# 797     0.165082   0.094315
# 798     0.151192   0.090601
# 799     0.148158   0.107407
#
# [800 rows x 13 columns]

# %%
data.columns = ["Missing Rate", "Mecanismo", "Repetição", "Dataset", "knn","lpr0","lpr1","lpr2","lpr3","mean","mice","pmivae","saei"]

data = data.drop(columns=["Missing Rate","Mecanismo", "Repetição","Dataset","lpr0","lpr1","lpr3"])

data = data[["mean","knn","mice","pmivae","saei","lpr2"]]

data
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    0.183439  0.129019  0.145508  0.233525  0.133545  0.142833
# 1    0.218947  0.119910  0.172214  0.247797  0.225019  0.152758
# 2    0.275906  0.249618  0.311658  0.271136  0.326975  0.289122
# 3    0.106660  0.084749  0.081713  0.150283  0.088466  0.126839
# 4    0.219823  0.200910  0.220482  0.243498  0.181726  0.241845
# ..        ...       ...       ...       ...       ...       ...
# 795  0.160961  0.113064  0.108997  0.160031  0.109323  0.122326
# 796  0.159768  0.105910  0.110679  0.159701  0.098915  0.117095
# 797  0.164514  0.111867  0.114222  0.165082  0.094315  0.126231
# 798  0.149492  0.095886  0.098048  0.151192  0.090601  0.110035
# 799  0.149763  0.106695  0.105933  0.148158  0.107407  0.110922
#
# [800 rows x 6 columns]

# %%
# fazendo o complemento para o teste estatístico
data_processed = data.max().max() + data.min().min() - data

print(data_processed)

data_processed.to_csv("todos_processed.csv", index=False)
# Out:
#          mean       knn      mice    pmivae      saei      lpr2
# 0    1.327999  1.382420  1.365930  1.277914  1.377894  1.368606
# 1    1.292491  1.391528  1.339224  1.263642  1.286420  1.358680
# 2    1.235533  1.261820  1.199781  1.240303  1.184463  1.222317
# 3    1.404779  1.426689  1.429726  1.361155  1.422972  1.384599
# 4    1.291616  1.310529  1.290957  1.267941  1.329712  1.269593
# ..        ...       ...       ...       ...       ...       ...
# 795  1.350478  1.398374  1.402442  1.351408  1.402116  1.389112
# 796  1.351671  1.405528  1.400760  1.351738  1.412524  1.394344
# 797  1.346925  1.399572  1.397217  1.346357  1.417124  1.385208
# 798  1.361946  1.415553  1.413391  1.360246  1.420837  1.401404
# 799  1.361676  1.404744  1.405506  1.363281  1.404032  1.400516
#
# [800 rows x 6 columns]
